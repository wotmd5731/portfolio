# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
n0 = np.random.rand(2,2)
df= pd.DataFrame(n0)
d
# Out:
# <AxesSubplot:>

# %%
import yfinance as yf

# %%
tick = yf.Ticker('SHV')

# %%
tick
# Out:
# yfinance.Ticker object <SHV>

# %%
h0= tick.history(period="max",auto_adjust=False)

# %%
h0['Close'].plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
plt.plot(h0['Close'].to_numpy())
